# %%
import torch
a = torch.randn(10)
a.view(2,-1)
# Out:
# tensor([[-0.0273,  0.7385,  0.9784,  0.0831,  2.5734],
#         [-0.5838,  2.3599, -0.5664, -0.4122, -0.2899]])

# %%
a = torch.randint(0,10,(2,8,2))
a
# Out:
# tensor([[[6, 3],
#          [2, 5],
#          [5, 8],
#          [9, 4],
#          [4, 0],
#          [6, 7],
#          [5, 8],
#          [3, 5]],
#
#         [[7, 9],
#          [5, 8],
#          [2, 0],
#          [1, 1],
#          [4, 9],
#          [5, 6],
#          [4, 3],
#          [9, 6]]])

# %%
a.view(2,4,-1)
# Out:
# tensor([[[6, 3, 2, 5],
#          [5, 8, 9, 4],
#          [4, 0, 6, 7],
#          [5, 8, 3, 5]],
#
#         [[7, 9, 5, 8],
#          [2, 0, 1, 1],
#          [4, 9, 5, 6],
#          [4, 3, 9, 6]]])

# %%
a[:,::2,:].shape,a[:,1::2,:].shape
# Out:
# (torch.Size([2, 4, 2]), torch.Size([2, 4, 2]))

# %%
(a.view(2,4,-1) == torch.cat([a[:,::2,:], a[:, 1::2,:]],dim = 2)).all()
# Out:
# tensor(True)

# %%
text = """The"""
tokens = text.encode()

# %%
len(text),len(tokens)
# Out:
# (3, 3)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 tokens[0].decode()
#
# AttributeError: 'int' object has no attribute 'decode'
